# %%
#Name:Vanshika Sohal
#Roll No.:1024170330
#Branch:COPC
#GROUP:2Q32
#Assignment:1

# %% [markdown]
# Question 1:  Create a variable `num` with value `15`. Reassign it to a float, then to a string. Display its type after each change.

# %%
num = 15
print(num, type(num))
num = 15.0
print(num, type(num))
num = "15"
print(num, type(num))

# %% [markdown]
# Question 2:Given the string variable `s = "100"`, convert it into an integer and perform an addition with the number `50`.

# %%
s = "100"
num = int(s)
result = num + 50
print(result)

# %% [markdown]
# Question 3:Try converting the string `"Hello"` into an integer using `int()`. What happens? How would you fix it if you want to represent `"Hello"` numerically?

# %%
s="Hello"
#s=(int)(s)  # This will raise an error  
#ValueError                                Traceback (most recent call last)
#Cell In[1], line 2
#     1 s="Hello"
#----> 2 s=(int)(s)

#ValueError: invalid literal for int() with base 10: 'Hello'
#converting string to integer
ascii_values = [ord(ch) for ch in s]
print(ascii_values)
# Out:
# [72, 101, 108, 108, 111]

# %% [markdown]
# Question 4:Create variables: `a = 12, b = 12.5, c = "12"`. Print the type of each and explain why they differ even though they look similar.

# %%
a=12
print(type(a))
b=12.5
print(type(b))
c="12"
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Question 5:Take a variable `val = "45.7"`. Convert it from string → float → int. Show intermediate results.

# %%
val="45.7"
valinfloat=float(val)
print(type(valinfloat))
valinint = int(valinfloat)#we cannot directly convert from string to int because it contains a decimal point but we can first convert it to float and then to int .
print(type(valinint))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# Question 6:Suppose you are collecting user input of age as a string "29". Convert it to integer and check if the person is eligible to vote (age ≥ 18)

# %%
s="29"
i=int(s)
print(i,type(i))
if(i>=18):
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# 29 <class 'int'>
# Eligible for voting

# %% [markdown]
# Question 7:Create a class Student with name and age attributes. Create a method display() that prints student details. Create an object of the class and display the details.

# %%
class Student:
    def __init__(self,name,age):
      self.name=name
      self.age=age

    def display(self):
        print("Name:",self.name)
        print("Age:",self.age)

student1=Student("Vanshika",18)
student1.display()
# Out:
# Name: Vanshika
# Age: 18
